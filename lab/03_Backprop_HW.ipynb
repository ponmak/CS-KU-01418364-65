# %% [markdown]
# ## Backpropagation Exercise
# In this exercise we will use backpropagation to train a multi-layer perceptron (with a single hidden layer).  We will experiment with different patterns and see how quickly or slowly the weights converge.  We will see the impact and interplay of different parameters such as learning rate, number of iterations, and number of data points.

# %%
#Preliminaries
from __future__ import division, print_function
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Fill out the code below so that it creates a multi-layer perceptron with a single hidden layer (with 4 nodes) and trains it via back-propagation.  Specifically your code should:
#
# 1. Initialize the weights to random values between -1 and 1
# 1. Perform the feed-forward computation
# 1. Compute the loss function
# 1. Calculate the gradients for all the weights via back-propagation
# 1. Update the weight matrices (using a learning_rate parameter)
# 1. Execute steps 2-5 for a fixed number of iterations
# 1. Plot the accuracies and log loss and observe how they change over time
#
#
# Once your code is running, try it for the different patterns below.
#
# - Which patterns was the neural network able to learn quickly and which took longer?
# - What learning rates and numbers of iterations worked well?
# - If you have time, try varying the size of the hidden layer and experiment with different activation functions (e.g. ReLu)

# %%
## This code below generates two x values and a y value according to different patterns
## It also creates a "bias" term (a vector of 1s)
## The goal is then to learn the mapping from x to y using a neural network via back-propagation

num_obs = 500
x_mat_1 = np.random.uniform(-1, 1, size=(num_obs, 2))
x_mat_bias = np.ones((num_obs, 1))
x_mat_full = np.concatenate((x_mat_1, x_mat_bias), axis=1)

# PICK ONE PATTERN BELOW and comment out the rest.

# # Circle pattern
y = (np.sqrt(x_mat_full[:, 0]**2 + x_mat_full[:, 1]**2)<.75).astype(int)

# # Diamond Pattern
# y = ((np.abs(x_mat_full[:, 0]) + np.abs(x_mat_full[:, 1]))<1).astype(int)

# # Centered square
# y = ((np.maximum(np.abs(x_mat_full[:, 0]),  np.abs(x_mat_full[:, 1])))<.5).astype(int)

# # Thick Right Angle pattern
# y = (((np.maximum((x_mat_full[:, 0]),  (x_mat_full[:, 1])))<.5) & ((np.maximum((x_mat_full[:, 0]),  (x_mat_full[:, 1])))>-.5)).astype(int)

# # Thin right angle pattern
# y = (((np.maximum((x_mat_full[:, 0]),  (x_mat_full[:, 1])))<.5) & ((np.maximum((x_mat_full[:, 0]),  (x_mat_full[:, 1])))>0)).astype(int)


print('shape of x_mat_full is {}'.format(x_mat_full.shape))
print('shape of y is {}'.format(y.shape))

fig,  ax = plt.subplots(figsize=(5,  5))
ax.plot(x_mat_full[y==1, 0], x_mat_full[y==1, 1], 'o', label='class 1', color='darkslateblue')
ax.plot(x_mat_full[y==0, 0], x_mat_full[y==0, 1], 'x', label='class 0', color='chocolate')
ax.grid(True)
ax.legend(loc='best')
# Out:
# shape of x_mat_full is (500, 3)
# shape of y is (500,)

# %%
x_mat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e06a1e925ae8> in <cell line: 1>()
# ----> 1 x_mat
#
# NameError: name 'x_mat' is not defined

# %% [markdown]
# Here are some helper functions

# %%
def sigmoid(x):
    """
    Sigmoid function
    """
    return 1.0 / (1.0 + np.exp(-x))


def loss_fn(y_true, y_pred, eps=1e-16):
    """
    Loss function we would like to optimize (minimize)
    We are using Logarithmic Loss
    http://scikit-learn.org/stable/modules/model_evaluation.html#log-loss
    """
    y_pred = np.maximum(y_pred, eps)
    y_pred = np.minimum(y_pred, (1-eps))
    return -(np.sum(y_true*np.log(y_pred)) + np.sum((1-y_true)*np.log(1-y_pred)))/len(y_true)


def forward_pass(W1, W2):
    """
    Does a forward computation of the neural network
    Takes the input `x_mat` (global variable) and produces the output `y_pred`
    Also produces the gradient of the log loss function
    """
    # First,  compute the new predictions `y_pred`
    z_2 = np.dot(x_mat, W_1)
    a_2 = sigmoid(z_2)
    z_3 = np.dot(a_2, W_2)
    y_pred = sigmoid(z_3).reshape((len(x_mat), ))
    # Now compute the gradient
    J_z_3_grad = -y + y_pred
    J_W_2_grad = np.dot(J_z_3_grad, a_2).reshape(-1, 1)
    a_2_z_2_grad = sigmoid(z_2)*(1-sigmoid(z_2))
    J_W_1_grad = (np.dot((J_z_3_grad).reshape(-1, 1),  W_2.reshape(-1, 1).T)*a_2_z_2_grad).T.dot(x_mat).T
    gradient = (J_W_1_grad, J_W_2_grad)

    # return
    return y_pred,  gradient


def plot_loss_accuracy(loss_vals, accuracies):
    fig = plt.figure(figsize=(16, 8))
    fig.suptitle('Log Loss and Accuracy over iterations')

    ax = fig.add_subplot(1, 2, 1)
    ax.plot(loss_vals)
    ax.grid(True)
    ax.set(xlabel='iterations', title='Log Loss')

    ax = fig.add_subplot(1, 2, 2)
    ax.plot(accuracies)
    ax.grid(True)
    ax.set(xlabel='iterations', title='Accuracy')

# %% [markdown]
# Complete the pseudocode below

# %%
(y_pred >= 0.5)[:10].astype('int')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4adaa894e237> in <cell line: 1>()
# ----> 1 (y_pred >= 0.5)[:10].astype('int')
#
# NameError: name 'y_pred' is not defined

# %%
y.shape
# Out:
# (500,)

# %%
#### Initialize the network parameters

np.random.seed(1241)

units = 4
W_1 = np.random.uniform(-1,1,size=(x_mat_full.shape[-1],units))
W_2 = np.random.uniform(-1,1,size=(units,1))
num_iter = 75000
learning_rate = 0.0001
x_mat = x_mat_full

loss_vals, accuracies = [], []
for i in range(num_iter):
    ### Do a forward computation,  and get the gradient
    y_pred, (J_W_1_grad , J_W_2_grad) = forward_pass(W_1, W_2)
    ## Update the weight matrices
    W_1 = W_1 - learning_rate * J_W_1_grad
    W_2 = W_2 - learning_rate * J_W_2_grad
    ### Compute the loss and accuracy
    loss_val = loss_fn(y_pred=y_pred, y_true=y)
    accuracy = (((y_pred >= 0.5).astype('int') == y).sum() / y.shape[0])

    loss_vals.append(loss_val)
    accuracies.append(accuracy)
    ## Print the loss and accuracy for every 200th iteration
    if i % 200 == 0:
        print(f"loss val in {i:4} : {loss_val:.5f}, accuracy in {i:4} : {accuracy}")
plot_loss_accuracy(loss_vals, accuracies)
# Out:
# loss val in    0 : 0.71223, accuracy in    0 : 0.6
# loss val in  200 : 0.67250, accuracy in  200 : 0.6
# loss val in  400 : 0.67170, accuracy in  400 : 0.6
# loss val in  600 : 0.67108, accuracy in  600 : 0.6
# loss val in  800 : 0.67052, accuracy in  800 : 0.6
# loss val in 1000 : 0.66999, accuracy in 1000 : 0.6
# loss val in 1200 : 0.66947, accuracy in 1200 : 0.6
# loss val in 1400 : 0.66895, accuracy in 1400 : 0.6
# loss val in 1600 : 0.66840, accuracy in 1600 : 0.6
# loss val in 1800 : 0.66783, accuracy in 1800 : 0.6
# loss val in 2000 : 0.66720, accuracy in 2000 : 0.6
# loss val in 2200 : 0.66650, accuracy in 2200 : 0.6
# loss val in 2400 : 0.66573, accuracy in 2400 : 0.6
# loss val in 2600 : 0.66487, accuracy in 2600 : 0.6
# loss val in 2800 : 0.66389, accuracy in 2800 : 0.6
# loss val in 3000 : 0.66277, accuracy in 3000 : 0.6
# loss val in 3200 : 0.66150, accuracy in 3200 : 0.6
# loss val in 3400 : 0.66003, accuracy in 3400 : 0.6
# loss val in 3600 : 0.65835, accuracy in 3600 : 0.6
# loss val in 3800 : 0.65641, accuracy in 3800 : 0.6
# loss val in 4000 : 0.65419, accuracy in 4000 : 0.6
# loss val in 4200 : 0.65163, accuracy in 4200 : 0.6
# loss val in 4400 : 0.64869, accuracy in 4400 : 0.6
# loss val in 4600 : 0.64533, accuracy in 4600 : 0.6
# loss val in 4800 : 0.64152, accuracy in 4800 : 0.6
# loss val in 5000 : 0.63720, accuracy in 5000 : 0.6
# loss val in 5200 : 0.63237, accuracy in 5200 : 0.594
# loss val in 5400 : 0.62700, accuracy in 5400 : 0.584
# loss val in 5600 : 0.62110, accuracy in 5600 : 0.578
# loss val in 5800 : 0.61472, accuracy in 5800 : 0.602
# loss val in 6000 : 0.60791, accuracy in 6000 : 0.622
# loss val in 6200 : 0.60075, accuracy in 6200 : 0.65
# loss val in 6400 : 0.59334, accuracy in 6400 : 0.664
# loss val in 6600 : 0.58582, accuracy in 6600 : 0.688
# loss val in 6800 : 0.57830, accuracy in 6800 : 0.722
# loss val in 7000 : 0.57091, accuracy in 7000 : 0.724
# loss val in 7200 : 0.56375, accuracy in 7200 : 0.732
# loss val in 7400 : 0.55693, accuracy in 7400 : 0.726
# loss val in 7600 : 0.55050, accuracy in 7600 : 0.726
# loss val in 7800 : 0.54451, accuracy in 7800 : 0.73
# loss val in 8000 : 0.53897, accuracy in 8000 : 0.732
# loss val in 8200 : 0.53389, accuracy in 8200 : 0.73
# loss val in 8400 : 0.52923, accuracy in 8400 : 0.734
# loss val in 8600 : 0.52496, accuracy in 8600 : 0.732
# loss val in 8800 : 0.52103, accuracy in 8800 : 0.73
# loss val in 9000 : 0.51737, accuracy in 9000 : 0.73
# loss val in 9200 : 0.51393, accuracy in 9200 : 0.732
# loss val in 9400 : 0.51062, accuracy in 9400 : 0.734
# loss val in 9600 : 0.50737, accuracy in 9600 : 0.734
# loss val in 9800 : 0.50410, accuracy in 9800 : 0.738
# loss val in 10000 : 0.50074, accuracy in 10000 : 0.742
# loss val in 10200 : 0.49718, accuracy in 10200 : 0.746
# loss val in 10400 : 0.49335, accuracy in 10400 : 0.746
# loss val in 10600 : 0.48915, accuracy in 10600 : 0.756
# loss val in 10800 : 0.48449, accuracy in 10800 : 0.762
# loss val in 11000 : 0.47929, accuracy in 11000 : 0.768
# loss val in 11200 : 0.47347, accuracy in 11200 : 0.776
# loss val in 11400 : 0.46697, accuracy in 11400 : 0.782
# loss val in 11600 : 0.45978, accuracy in 11600 : 0.79
# loss val in 11800 : 0.45189, accuracy in 11800 : 0.798
# loss val in 12000 : 0.44335, accuracy in 12000 : 0.81
# loss val in 12200 : 0.43425, accuracy in 12200 : 0.826
# loss val in 12400 : 0.42470, accuracy in 12400 : 0.838
# loss val in 12600 : 0.41488, accuracy in 12600 : 0.844
# loss val in 12800 : 0.40494, accuracy in 12800 : 0.854
# loss val in 13000 : 0.39505, accuracy in 13000 : 0.86
# loss val in 13200 : 0.38537, accuracy in 13200 : 0.88
# loss val in 13400 : 0.37604, accuracy in 13400 : 0.89
# loss val in 13600 : 0.36715, accuracy in 13600 : 0.892
# loss val in 13800 : 0.35878, accuracy in 13800 : 0.9
# loss val in 14000 : 0.35095, accuracy in 14000 : 0.898
# loss val in 14200 : 0.34369, accuracy in 14200 : 0.906
# loss val in 14400 : 0.33696, accuracy in 14400 : 0.91
# loss val in 14600 : 0.33074, accuracy in 14600 : 0.912
# loss val in 14800 : 0.32500, accuracy in 14800 : 0.912
# loss val in 15000 : 0.31969, accuracy in 15000 : 0.91
# loss val in 15200 : 0.31477, accuracy in 15200 : 0.914
# loss val in 15400 : 0.31020, accuracy in 15400 : 0.912
# loss val in 15600 : 0.30593, accuracy in 15600 : 0.914
# loss val in 15800 : 0.30195, accuracy in 15800 : 0.918
# loss val in 16000 : 0.29821, accuracy in 16000 : 0.918
# loss val in 16200 : 0.29469, accuracy in 16200 : 0.914
# loss val in 16400 : 0.29137, accuracy in 16400 : 0.916
# loss val in 16600 : 0.28823, accuracy in 16600 : 0.916
# loss val in 16800 : 0.28526, accuracy in 16800 : 0.916
# loss val in 17000 : 0.28243, accuracy in 17000 : 0.916
# loss val in 17200 : 0.27974, accuracy in 17200 : 0.916
# loss val in 17400 : 0.27718, accuracy in 17400 : 0.916
# loss val in 17600 : 0.27473, accuracy in 17600 : 0.918
# loss val in 17800 : 0.27239, accuracy in 17800 : 0.92
# loss val in 18000 : 0.27014, accuracy in 18000 : 0.92
# loss val in 18200 : 0.26799, accuracy in 18200 : 0.92
# loss val in 18400 : 0.26592, accuracy in 18400 : 0.92
# loss val in 18600 : 0.26393, accuracy in 18600 : 0.92
# loss val in 18800 : 0.26201, accuracy in 18800 : 0.918
# loss val in 19000 : 0.26016, accuracy in 19000 : 0.918
# loss val in 19200 : 0.25838, accuracy in 19200 : 0.918
# loss val in 19400 : 0.25666, accuracy in 19400 : 0.92
# loss val in 19600 : 0.25499, accuracy in 19600 : 0.92
# loss val in 19800 : 0.25338, accuracy in 19800 : 0.92
# loss val in 20000 : 0.25181, accuracy in 20000 : 0.92
# loss val in 20200 : 0.25030, accuracy in 20200 : 0.92
# loss val in 20400 : 0.24882, accuracy in 20400 : 0.918
# loss val in 20600 : 0.24739, accuracy in 20600 : 0.918
# loss val in 20800 : 0.24600, accuracy in 20800 : 0.92
# loss val in 21000 : 0.24464, accuracy in 21000 : 0.92
# loss val in 21200 : 0.24332, accuracy in 21200 : 0.92
# loss val in 21400 : 0.24203, accuracy in 21400 : 0.92
# loss val in 21600 : 0.24077, accuracy in 21600 : 0.92
# loss val in 21800 : 0.23954, accuracy in 21800 : 0.92
# loss val in 22000 : 0.23834, accuracy in 22000 : 0.922
# loss val in 22200 : 0.23717, accuracy in 22200 : 0.922
# loss val in 22400 : 0.23602, accuracy in 22400 : 0.92
# loss val in 22600 : 0.23489, accuracy in 22600 : 0.92
# loss val in 22800 : 0.23379, accuracy in 22800 : 0.92
# loss val in 23000 : 0.23271, accuracy in 23000 : 0.92
# loss val in 23200 : 0.23164, accuracy in 23200 : 0.92
# loss val in 23400 : 0.23060, accuracy in 23400 : 0.92
# loss val in 23600 : 0.22958, accuracy in 23600 : 0.92
# loss val in 23800 : 0.22857, accuracy in 23800 : 0.922
# loss val in 24000 : 0.22758, accuracy in 24000 : 0.922
# loss val in 24200 : 0.22661, accuracy in 24200 : 0.922
# loss val in 24400 : 0.22565, accuracy in 24400 : 0.922
# loss val in 24600 : 0.22471, accuracy in 24600 : 0.922
# loss val in 24800 : 0.22378, accuracy in 24800 : 0.922
# loss val in 25000 : 0.22287, accuracy in 25000 : 0.922
# loss val in 25200 : 0.22197, accuracy in 25200 : 0.922
# loss val in 25400 : 0.22108, accuracy in 25400 : 0.922
# loss val in 25600 : 0.22020, accuracy in 25600 : 0.92
# loss val in 25800 : 0.21933, accuracy in 25800 : 0.918
# loss val in 26000 : 0.21848, accuracy in 26000 : 0.918
# loss val in 26200 : 0.21764, accuracy in 26200 : 0.918
# loss val in 26400 : 0.21680, accuracy in 26400 : 0.918
# loss val in 26600 : 0.21598, accuracy in 26600 : 0.92
# loss val in 26800 : 0.21516, accuracy in 26800 : 0.922
# loss val in 27000 : 0.21436, accuracy in 27000 : 0.922
# loss val in 27200 : 0.21356, accuracy in 27200 : 0.92
# loss val in 27400 : 0.21278, accuracy in 27400 : 0.92
# loss val in 27600 : 0.21200, accuracy in 27600 : 0.92
# loss val in 27800 : 0.21123, accuracy in 27800 : 0.92
# loss val in 28000 : 0.21046, accuracy in 28000 : 0.922
# loss val in 28200 : 0.20971, accuracy in 28200 : 0.924
# loss val in 28400 : 0.20896, accuracy in 28400 : 0.928
# loss val in 28600 : 0.20822, accuracy in 28600 : 0.928
# loss val in 28800 : 0.20749, accuracy in 28800 : 0.928
# loss val in 29000 : 0.20676, accuracy in 29000 : 0.93
# loss val in 29200 : 0.20604, accuracy in 29200 : 0.93
# loss val in 29400 : 0.20532, accuracy in 29400 : 0.93
# loss val in 29600 : 0.20461, accuracy in 29600 : 0.93
# loss val in 29800 : 0.20391, accuracy in 29800 : 0.93
# loss val in 30000 : 0.20322, accuracy in 30000 : 0.93
# loss val in 30200 : 0.20252, accuracy in 30200 : 0.93
# loss val in 30400 : 0.20184, accuracy in 30400 : 0.932
# loss val in 30600 : 0.20116, accuracy in 30600 : 0.932
# loss val in 30800 : 0.20048, accuracy in 30800 : 0.932
# loss val in 31000 : 0.19981, accuracy in 31000 : 0.932
# loss val in 31200 : 0.19915, accuracy in 31200 : 0.932
# loss val in 31400 : 0.19849, accuracy in 31400 : 0.932
# loss val in 31600 : 0.19783, accuracy in 31600 : 0.932
# loss val in 31800 : 0.19718, accuracy in 31800 : 0.932
# loss val in 32000 : 0.19654, accuracy in 32000 : 0.932
# loss val in 32200 : 0.19590, accuracy in 32200 : 0.932
# loss val in 32400 : 0.19526, accuracy in 32400 : 0.934
# loss val in 32600 : 0.19463, accuracy in 32600 : 0.934
# loss val in 32800 : 0.19400, accuracy in 32800 : 0.934
# loss val in 33000 : 0.19337, accuracy in 33000 : 0.934
# loss val in 33200 : 0.19275, accuracy in 33200 : 0.934
# loss val in 33400 : 0.19213, accuracy in 33400 : 0.934
# loss val in 33600 : 0.19152, accuracy in 33600 : 0.934
# loss val in 33800 : 0.19091, accuracy in 33800 : 0.932
# loss val in 34000 : 0.19030, accuracy in 34000 : 0.932
# loss val in 34200 : 0.18970, accuracy in 34200 : 0.934
# loss val in 34400 : 0.18910, accuracy in 34400 : 0.934
# loss val in 34600 : 0.18851, accuracy in 34600 : 0.934
# loss val in 34800 : 0.18792, accuracy in 34800 : 0.934
# loss val in 35000 : 0.18733, accuracy in 35000 : 0.934
# loss val in 35200 : 0.18674, accuracy in 35200 : 0.936
# loss val in 35400 : 0.18616, accuracy in 35400 : 0.936
# loss val in 35600 : 0.18558, accuracy in 35600 : 0.934
# loss val in 35800 : 0.18500, accuracy in 35800 : 0.936
# loss val in 36000 : 0.18443, accuracy in 36000 : 0.936
# loss val in 36200 : 0.18386, accuracy in 36200 : 0.936
# loss val in 36400 : 0.18329, accuracy in 36400 : 0.936
# loss val in 36600 : 0.18273, accuracy in 36600 : 0.94
# loss val in 36800 : 0.18217, accuracy in 36800 : 0.94
# loss val in 37000 : 0.18161, accuracy in 37000 : 0.94
# loss val in 37200 : 0.18106, accuracy in 37200 : 0.94
# loss val in 37400 : 0.18050, accuracy in 37400 : 0.94
# loss val in 37600 : 0.17995, accuracy in 37600 : 0.94
# loss val in 37800 : 0.17940, accuracy in 37800 : 0.94
# loss val in 38000 : 0.17886, accuracy in 38000 : 0.94
# loss val in 38200 : 0.17832, accuracy in 38200 : 0.938
# loss val in 38400 : 0.17778, accuracy in 38400 : 0.938
# loss val in 38600 : 0.17724, accuracy in 38600 : 0.938
# loss val in 38800 : 0.17670, accuracy in 38800 : 0.94
# loss val in 39000 : 0.17617, accuracy in 39000 : 0.94
# loss val in 39200 : 0.17564, accuracy in 39200 : 0.94
# loss val in 39400 : 0.17511, accuracy in 39400 : 0.94
# loss val in 39600 : 0.17459, accuracy in 39600 : 0.94
# loss val in 39800 : 0.17406, accuracy in 39800 : 0.94
# loss val in 40000 : 0.17354, accuracy in 40000 : 0.942
# loss val in 40200 : 0.17302, accuracy in 40200 : 0.944
# loss val in 40400 : 0.17251, accuracy in 40400 : 0.944
# loss val in 40600 : 0.17199, accuracy in 40600 : 0.944
# loss val in 40800 : 0.17148, accuracy in 40800 : 0.944
# loss val in 41000 : 0.17097, accuracy in 41000 : 0.944
# loss val in 41200 : 0.17046, accuracy in 41200 : 0.944
# loss val in 41400 : 0.16996, accuracy in 41400 : 0.944
# loss val in 41600 : 0.16945, accuracy in 41600 : 0.944
# loss val in 41800 : 0.16895, accuracy in 41800 : 0.944
# loss val in 42000 : 0.16845, accuracy in 42000 : 0.946
# loss val in 42200 : 0.16795, accuracy in 42200 : 0.946
# loss val in 42400 : 0.16745, accuracy in 42400 : 0.946
# loss val in 42600 : 0.16696, accuracy in 42600 : 0.948
# loss val in 42800 : 0.16647, accuracy in 42800 : 0.948
# loss val in 43000 : 0.16598, accuracy in 43000 : 0.948
# loss val in 43200 : 0.16549, accuracy in 43200 : 0.948
# loss val in 43400 : 0.16500, accuracy in 43400 : 0.948
# loss val in 43600 : 0.16451, accuracy in 43600 : 0.948
# loss val in 43800 : 0.16403, accuracy in 43800 : 0.948
# loss val in 44000 : 0.16355, accuracy in 44000 : 0.95
# loss val in 44200 : 0.16307, accuracy in 44200 : 0.95
# loss val in 44400 : 0.16259, accuracy in 44400 : 0.952
# loss val in 44600 : 0.16211, accuracy in 44600 : 0.952
# loss val in 44800 : 0.16163, accuracy in 44800 : 0.952
# loss val in 45000 : 0.16116, accuracy in 45000 : 0.954
# loss val in 45200 : 0.16069, accuracy in 45200 : 0.954
# loss val in 45400 : 0.16021, accuracy in 45400 : 0.954
# loss val in 45600 : 0.15974, accuracy in 45600 : 0.954
# loss val in 45800 : 0.15928, accuracy in 45800 : 0.954
# loss val in 46000 : 0.15881, accuracy in 46000 : 0.954
# loss val in 46200 : 0.15834, accuracy in 46200 : 0.954
# loss val in 46400 : 0.15788, accuracy in 46400 : 0.954
# loss val in 46600 : 0.15742, accuracy in 46600 : 0.952
# loss val in 46800 : 0.15696, accuracy in 46800 : 0.952
# loss val in 47000 : 0.15650, accuracy in 47000 : 0.952
# loss val in 47200 : 0.15604, accuracy in 47200 : 0.952
# loss val in 47400 : 0.15559, accuracy in 47400 : 0.952
# loss val in 47600 : 0.15513, accuracy in 47600 : 0.956
# loss val in 47800 : 0.15468, accuracy in 47800 : 0.956
# loss val in 48000 : 0.15423, accuracy in 48000 : 0.956
# loss val in 48200 : 0.15378, accuracy in 48200 : 0.956
# loss val in 48400 : 0.15333, accuracy in 48400 : 0.956
# loss val in 48600 : 0.15288, accuracy in 48600 : 0.958
# loss val in 48800 : 0.15243, accuracy in 48800 : 0.958
# loss val in 49000 : 0.15199, accuracy in 49000 : 0.958
# loss val in 49200 : 0.15155, accuracy in 49200 : 0.96
# loss val in 49400 : 0.15111, accuracy in 49400 : 0.96
# loss val in 49600 : 0.15067, accuracy in 49600 : 0.96
# loss val in 49800 : 0.15023, accuracy in 49800 : 0.96
# loss val in 50000 : 0.14979, accuracy in 50000 : 0.96
# loss val in 50200 : 0.14936, accuracy in 50200 : 0.96
# loss val in 50400 : 0.14893, accuracy in 50400 : 0.96
# loss val in 50600 : 0.14850, accuracy in 50600 : 0.96
# loss val in 50800 : 0.14807, accuracy in 50800 : 0.96
# loss val in 51000 : 0.14764, accuracy in 51000 : 0.96
# loss val in 51200 : 0.14722, accuracy in 51200 : 0.96
# loss val in 51400 : 0.14679, accuracy in 51400 : 0.96
# loss val in 51600 : 0.14637, accuracy in 51600 : 0.96
# loss val in 51800 : 0.14595, accuracy in 51800 : 0.96
# loss val in 52000 : 0.14554, accuracy in 52000 : 0.96
# loss val in 52200 : 0.14512, accuracy in 52200 : 0.96
# loss val in 52400 : 0.14471, accuracy in 52400 : 0.96
# loss val in 52600 : 0.14430, accuracy in 52600 : 0.958
# loss val in 52800 : 0.14389, accuracy in 52800 : 0.958
# loss val in 53000 : 0.14349, accuracy in 53000 : 0.958
# loss val in 53200 : 0.14309, accuracy in 53200 : 0.958
# loss val in 53400 : 0.14269, accuracy in 53400 : 0.958
# loss val in 53600 : 0.14229, accuracy in 53600 : 0.96
# loss val in 53800 : 0.14190, accuracy in 53800 : 0.96
# loss val in 54000 : 0.14151, accuracy in 54000 : 0.96
# loss val in 54200 : 0.14112, accuracy in 54200 : 0.962
# loss val in 54400 : 0.14073, accuracy in 54400 : 0.962
# loss val in 54600 : 0.14035, accuracy in 54600 : 0.962
# loss val in 54800 : 0.13997, accuracy in 54800 : 0.962
# loss val in 55000 : 0.13960, accuracy in 55000 : 0.962
# loss val in 55200 : 0.13922, accuracy in 55200 : 0.964
# loss val in 55400 : 0.13886, accuracy in 55400 : 0.964
# loss val in 55600 : 0.13849, accuracy in 55600 : 0.964
# loss val in 55800 : 0.13813, accuracy in 55800 : 0.964
# loss val in 56000 : 0.13777, accuracy in 56000 : 0.964
# loss val in 56200 : 0.13741, accuracy in 56200 : 0.964
# loss val in 56400 : 0.13706, accuracy in 56400 : 0.964
# loss val in 56600 : 0.13671, accuracy in 56600 : 0.964
# loss val in 56800 : 0.13637, accuracy in 56800 : 0.964
# loss val in 57000 : 0.13603, accuracy in 57000 : 0.964
# loss val in 57200 : 0.13569, accuracy in 57200 : 0.964
# loss val in 57400 : 0.13536, accuracy in 57400 : 0.964
# loss val in 57600 : 0.13503, accuracy in 57600 : 0.964
# loss val in 57800 : 0.13470, accuracy in 57800 : 0.964
# loss val in 58000 : 0.13438, accuracy in 58000 : 0.964
# loss val in 58200 : 0.13406, accuracy in 58200 : 0.964
# loss val in 58400 : 0.13375, accuracy in 58400 : 0.964
# loss val in 58600 : 0.13344, accuracy in 58600 : 0.968
# loss val in 58800 : 0.13313, accuracy in 58800 : 0.968
# loss val in 59000 : 0.13283, accuracy in 59000 : 0.968
# loss val in 59200 : 0.13253, accuracy in 59200 : 0.968
# loss val in 59400 : 0.13224, accuracy in 59400 : 0.968
# loss val in 59600 : 0.13195, accuracy in 59600 : 0.968
# loss val in 59800 : 0.13166, accuracy in 59800 : 0.968
# loss val in 60000 : 0.13138, accuracy in 60000 : 0.968
# loss val in 60200 : 0.13110, accuracy in 60200 : 0.968
# loss val in 60400 : 0.13082, accuracy in 60400 : 0.964
# loss val in 60600 : 0.13055, accuracy in 60600 : 0.964
# loss val in 60800 : 0.13028, accuracy in 60800 : 0.964
# loss val in 61000 : 0.13002, accuracy in 61000 : 0.964
# loss val in 61200 : 0.12976, accuracy in 61200 : 0.964
# loss val in 61400 : 0.12950, accuracy in 61400 : 0.964
# loss val in 61600 : 0.12924, accuracy in 61600 : 0.964
# loss val in 61800 : 0.12899, accuracy in 61800 : 0.964
# loss val in 62000 : 0.12875, accuracy in 62000 : 0.964
# loss val in 62200 : 0.12850, accuracy in 62200 : 0.964
# loss val in 62400 : 0.12826, accuracy in 62400 : 0.964
# loss val in 62600 : 0.12803, accuracy in 62600 : 0.964
# loss val in 62800 : 0.12779, accuracy in 62800 : 0.964
# loss val in 63000 : 0.12756, accuracy in 63000 : 0.964
# loss val in 63200 : 0.12733, accuracy in 63200 : 0.964
# loss val in 63400 : 0.12711, accuracy in 63400 : 0.966
# loss val in 63600 : 0.12689, accuracy in 63600 : 0.966
# loss val in 63800 : 0.12667, accuracy in 63800 : 0.966
# loss val in 64000 : 0.12645, accuracy in 64000 : 0.966
# loss val in 64200 : 0.12624, accuracy in 64200 : 0.968
# loss val in 64400 : 0.12603, accuracy in 64400 : 0.968
# loss val in 64600 : 0.12582, accuracy in 64600 : 0.968
# loss val in 64800 : 0.12562, accuracy in 64800 : 0.968
# loss val in 65000 : 0.12542, accuracy in 65000 : 0.968
# loss val in 65200 : 0.12522, accuracy in 65200 : 0.968
# loss val in 65400 : 0.12502, accuracy in 65400 : 0.968
# loss val in 65600 : 0.12483, accuracy in 65600 : 0.968
# loss val in 65800 : 0.12463, accuracy in 65800 : 0.968
# loss val in 66000 : 0.12444, accuracy in 66000 : 0.968
# loss val in 66200 : 0.12426, accuracy in 66200 : 0.968
# loss val in 66400 : 0.12407, accuracy in 66400 : 0.968
# loss val in 66600 : 0.12389, accuracy in 66600 : 0.968
# loss val in 66800 : 0.12371, accuracy in 66800 : 0.968
# loss val in 67000 : 0.12353, accuracy in 67000 : 0.968
# loss val in 67200 : 0.12335, accuracy in 67200 : 0.968
# loss val in 67400 : 0.12318, accuracy in 67400 : 0.968
# loss val in 67600 : 0.12301, accuracy in 67600 : 0.968
# loss val in 67800 : 0.12284, accuracy in 67800 : 0.968
# loss val in 68000 : 0.12267, accuracy in 68000 : 0.97
# loss val in 68200 : 0.12250, accuracy in 68200 : 0.97
# loss val in 68400 : 0.12234, accuracy in 68400 : 0.97
# loss val in 68600 : 0.12217, accuracy in 68600 : 0.97
# loss val in 68800 : 0.12201, accuracy in 68800 : 0.97
# loss val in 69000 : 0.12185, accuracy in 69000 : 0.97
# loss val in 69200 : 0.12170, accuracy in 69200 : 0.97
# loss val in 69400 : 0.12154, accuracy in 69400 : 0.97
# loss val in 69600 : 0.12139, accuracy in 69600 : 0.97
# loss val in 69800 : 0.12123, accuracy in 69800 : 0.972
# loss val in 70000 : 0.12108, accuracy in 70000 : 0.972
# loss val in 70200 : 0.12093, accuracy in 70200 : 0.972
# loss val in 70400 : 0.12078, accuracy in 70400 : 0.972
# loss val in 70600 : 0.12064, accuracy in 70600 : 0.974
# loss val in 70800 : 0.12049, accuracy in 70800 : 0.976
# loss val in 71000 : 0.12034, accuracy in 71000 : 0.976
# loss val in 71200 : 0.12020, accuracy in 71200 : 0.976
# loss val in 71400 : 0.12006, accuracy in 71400 : 0.976
# loss val in 71600 : 0.11992, accuracy in 71600 : 0.976
# loss val in 71800 : 0.11978, accuracy in 71800 : 0.976
# loss val in 72000 : 0.11964, accuracy in 72000 : 0.976
# loss val in 72200 : 0.11950, accuracy in 72200 : 0.976
# loss val in 72400 : 0.11937, accuracy in 72400 : 0.976
# loss val in 72600 : 0.11923, accuracy in 72600 : 0.976
# loss val in 72800 : 0.11910, accuracy in 72800 : 0.976
# loss val in 73000 : 0.11897, accuracy in 73000 : 0.976
# loss val in 73200 : 0.11884, accuracy in 73200 : 0.976
# loss val in 73400 : 0.11871, accuracy in 73400 : 0.976
# loss val in 73600 : 0.11858, accuracy in 73600 : 0.976
# loss val in 73800 : 0.11845, accuracy in 73800 : 0.976
# loss val in 74000 : 0.11832, accuracy in 74000 : 0.976
# loss val in 74200 : 0.11819, accuracy in 74200 : 0.976
# loss val in 74400 : 0.11807, accuracy in 74400 : 0.976
# loss val in 74600 : 0.11794, accuracy in 74600 : 0.976
# loss val in 74800 : 0.11782, accuracy in 74800 : 0.976

# %%
#### Plot the predicted answers with mistakes in yellow
import sklearn.metrics as metric
fig,  ax = plt.subplots(figsize=(5,  5))
ax.plot(
    x_mat_full[y==1, 0],
    x_mat_full[y==1, 1],
    'o',
    label='class 1',
    color='darkslateblue'
)
ax.plot(
    x_mat_full[y==0, 0],
    x_mat_full[y==0, 1],
    'x',
    label='class 0',
    color='chocolate'
)

# %%
# confusion_matrix
confusion = metric.confusion_matrix(y, (y_pred >= 0.5).astype('int'))
# display
disp = metric.ConfusionMatrixDisplay(confusion_matrix=confusion)
disp.plot()
